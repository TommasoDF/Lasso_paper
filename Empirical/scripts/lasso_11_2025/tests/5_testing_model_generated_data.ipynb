# %%
import os
os.getcwd()
os.chdir('/Users/tommasodifrancesco/Desktop/Lasso_paper/Empirical/scripts/lasso_11_2025')

# %%
# Generate simulated data for testing purposes

import matplotlib.pyplot as plt

import pandas as pd
import csv
import pickle
from sklearn.linear_model import Lasso
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import numpy as np
import pyarrow as pa
import pyarrow.parquet as pq
from pathlib import Path
import os
import random
from itertools import product



from stage1 import lasso_rolling_window, calculate_r_squared

from stage2 import estimate_kappa_curve_fit, compute_alm_returns, compute_stage2_r_squared
from grid_search import estimate_single_config

# %%
#loading data
df = pd.read_csv('/Users/tommasodifrancesco/Desktop/Lasso_paper/Theory/simulation_data.csv')

# %%
# data
y = df['r'].values
X = df.drop(columns=['r']).values
#drop first column which is index
X = X[:,1:]
random.seed(42)

# %%
#estimation
results = estimate_single_config(X, y, window_size=30, n_lags = 1, lambda_val = 0.5)

# %%
summary = results['summary']
summary
# Out:
# {'window_size': 30,
#  'n_lags': 1,
#  'lambda': 0.5,
#  'r2_insample_stage1': np.float64(-0.03125031038758639),
#  'r2_oos_stage1': np.float64(-0.00010148938923948414),
#  'r2_insample_stage2': np.float64(-6.280753694909436e-10),
#  'r2_oos_stage2': np.float64(-0.0006994652827607695),
#  'kappa': np.float64(0.5),
#  'kappa_tstat': nan,
#  'intercept': np.float64(-1.0907632386632424e-05),
#  'intercept_tstat': np.float64(-1.0504317215490382),
#  'n_observations': 9969,
#  'n_windows': 9970,
#  'n_oos_predictions_stage2': nan}
